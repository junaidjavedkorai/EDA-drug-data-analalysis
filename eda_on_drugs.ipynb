# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('drug_abuse_data.csv')
df
# Out:
#        state  state_code  year  drug_deaths  population  labor_force  \
# 0    Alabama           1  1999          195     4430141      2140296
# 1    Alabama           1  2000          232     4447100      2133223
# 2    Alabama           1  2001          253     4467634      2115401
# 3    Alabama           1  2002          248     4480089      2106161
# 4    Alabama           1  2003          255     4503491      2120225
# ..       ...         ...   ...          ...         ...          ...
# 913  Wyoming          56  2012           99      576412       307267
# 914  Wyoming          56  2013           99      582658       306608
# 915  Wyoming          56  2014          112      584153       306331
# 916  Wyoming          56  2015           99      586107       304775
# 917  Wyoming          56  2016          103      585501       300922
#
#      employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# ...

# %%
rows,cols = df.shape
print('Total rows in the dataset = ',rows)
print('Total columns in the dataset= ',cols)
# Out:
# Total rows in the dataset =  918
# Total columns in the dataset=  11

# %%
# lets check the information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   state                    918 non-null    object
#  1   state_code               918 non-null    int64
#  2   year                     918 non-null    int64
#  3   drug_deaths              918 non-null    int64
#  4   population               918 non-null    int64
#  5   labor_force              918 non-null    int64
#  6   employment               918 non-null    int64
#  7   unemployment             918 non-null    int64
#  8   unemployment_rate        918 non-null    float64
#  9   cpi_all_urban_consumers  918 non-null    float64
#  10  gdp_per_capita           918 non-null    int64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 79.0+ KB

# %%
df.dtypes
# Out:
# state                       object
# state_code                   int64
# year                         int64
# drug_deaths                  int64
# population                   int64
# labor_force                  int64
# employment                   int64
# unemployment                 int64
# unemployment_rate          float64
# cpi_all_urban_consumers    float64
# gdp_per_capita               int64
# dtype: object

# %%
# checking the null values
df.isnull().sum()
# Out:
# state                      0
# state_code                 0
# year                       0
# drug_deaths                0
# population                 0
# labor_force                0
# employment                 0
# unemployment               0
# unemployment_rate          0
# cpi_all_urban_consumers    0
# gdp_per_capita             0
# dtype: int64

# %%
df.head()
# Out:
#      state  state_code  year  drug_deaths  population  labor_force  \
# 0  Alabama           1  1999          195     4430141      2140296
# 1  Alabama           1  2000          232     4447100      2133223
# 2  Alabama           1  2001          253     4467634      2115401
# 3  Alabama           1  2002          248     4480089      2106161
# 4  Alabama           1  2003          255     4503491      2120225
#
#    employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# 0     2038889        101407                4.7                    166.6
# 1     2035594         97629                4.6                    172.2
# 2     2006884        108517                5.1                    177.1
# 3     1981919        124242                5.9                    179.9
# 4     1992732        127493                6.0                    184.0
#
#    gdp_per_capita
# 0           33106
# 1           33106
# 2           33312
# 3           34068
# 4           34855

# %%
df.loc[56, :]
# Out:
# state                      Arkansas
# state_code                        5
# year                           2001
# drug_deaths                     131
# population                  2691571
# labor_force                 1253456
# employment                  1191273
# unemployment                  62183
# unemployment_rate               5.0
# cpi_all_urban_consumers       177.1
# gdp_per_capita                31685
# Name: 56, dtype: object

# %%
df.describe()
# Out:
#        state_code         year  drug_deaths    population   labor_force  \
# count  918.000000   918.000000   918.000000  9.180000e+02  9.180000e+02
# mean    28.960784  2007.500000   741.546841  5.921292e+06  2.957883e+06
# std     15.685381     5.190956   833.074622  6.631564e+06  3.253066e+06
# min      1.000000  1999.000000    13.000000  4.917800e+05  2.627580e+05
# 25%     16.000000  2003.000000   168.000000  1.599830e+06  7.696502e+05
# 50%     29.000000  2007.500000   514.000000  4.131636e+06  1.991038e+06
# 75%     42.000000  2012.000000   963.500000  6.686474e+06  3.470114e+06
# max     56.000000  2016.000000  5094.000000  3.925002e+07  1.909366e+07
#
#          employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# count  9.180000e+02  9.180000e+02         918.000000               918.000000
# mean   2.776227e+06  1.816554e+05           5.716776               206.782667
# std    3.032583e+06  2.409780e+05           1.985356                23.726850
# ...

# %%
df
# Out:
#        state  state_code  year  drug_deaths  population  labor_force  \
# 0    Alabama           1  1999          195     4430141      2140296
# 1    Alabama           1  2000          232     4447100      2133223
# 2    Alabama           1  2001          253     4467634      2115401
# 3    Alabama           1  2002          248     4480089      2106161
# 4    Alabama           1  2003          255     4503491      2120225
# ..       ...         ...   ...          ...         ...          ...
# 913  Wyoming          56  2012           99      576412       307267
# 914  Wyoming          56  2013           99      582658       306608
# 915  Wyoming          56  2014          112      584153       306331
# 916  Wyoming          56  2015           99      586107       304775
# 917  Wyoming          56  2016          103      585501       300922
#
#      employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# ...

# %%
df['year'].value_counts()
# Out:
# 1999    51
# 2000    51
# 2015    51
# 2014    51
# 2013    51
# 2012    51
# 2011    51
# 2010    51
# 2009    51
# 2008    51
# 2007    51
# 2006    51
# 2005    51
# 2004    51
# 2003    51
# 2002    51
# 2001    51
# 2016    51
# Name: year, dtype: int64

# %%
df['state'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016], dtype=int64)

# %%
df.iloc[df['year'].idxmax()]
# Out:
# state                      Alabama
# state_code                       1
# year                          2016
# drug_deaths                    855
# population                 4863300
# labor_force                2173175
# employment                 2045624
# unemployment                127551
# unemployment_rate              5.9
# cpi_all_urban_consumers    240.007
# gdp_per_capita               37402
# Name: 17, dtype: object

# %%
df.iloc[df['state_code'].idxmax()]
# Out:
# state                      Wyoming
# state_code                      56
# year                          1999
# drug_deaths                     21
# population                  491780
# labor_force                 262758
# employment                  250605
# unemployment                 12153
# unemployment_rate              4.6
# cpi_all_urban_consumers      166.6
# gdp_per_capita               49380
# Name: 900, dtype: object

# %%
df['state_code'].unique().value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SKENTE~1\AppData\Local\Temp/ipykernel_9088/699834962.py in <module>
# ----> 1 df['state_code'].unique().value_count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_count'

# %%
df['state_code'].value_counts()
# Out:
# 1     18
# 42    18
# 32    18
# 33    18
# 34    18
# 35    18
# 36    18
# 37    18
# 38    18
# 39    18
# 40    18
# 41    18
# 44    18
# 30    18
# 45    18
# 46    18
# 47    18
# 48    18
# 49    18
# 50    18
# 51    18
# 53    18
# 54    18
# 55    18
# 31    18
# 29    18
# 2     18
# 16    18
# 4     18
# 5     18
# 6     18
# 8     18
# 9     18
# 10    18
# 11    18
# 12    18
# 13    18
# 15    18
# 17    18
# 28    18
# 18    18
# 19    18
# 20    18
# 21    18
# 22    18
# 23    18
# 24    18
# 25    18
# 26    18
# 27    18
# 56    18
# Name: state_code, dtype: int64

# %% [markdown]
# ##### most deaths in the year

# %%
df.iloc[df['drug_deaths'].idxmax()]
# Out:
# state                      California
# state_code                          6
# year                             2016
# drug_deaths                      5094
# population                   39250017
# labor_force                  19093658
# employment                   18048827
# unemployment                  1044831
# unemployment_rate                 5.5
# cpi_all_urban_consumers       240.007
# gdp_per_capita                  59117
# Name: 89, dtype: object

# %% [markdown]
# ##### Minimum deaths in the year

# %%
df.iloc[df[df['drug_deaths'].ge(0)].drug_deaths.idxmin()]
# Out:
# state                      North Dakota
# state_code                           38
# year                               2005
# drug_deaths                          13
# population                       646089
# labor_force                      355545
# employment                       343508
# unemployment                      12037
# unemployment_rate                   3.4
# cpi_all_urban_consumers           195.3
# gdp_per_capita                    41272
# Name: 618, dtype: object

# %% [markdown]
# ### List of states

# %%
df['state'].unique().tolist()
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
### Total states
len(df['state'].unique().tolist())
# Out:
# 51

# %%
df['state'].value_counts()
# Out:
# Alabama                 18
# Pennsylvania            18
# Nevada                  18
# New Hampshire           18
# New Jersey              18
# New Mexico              18
# New York                18
# North Carolina          18
# North Dakota            18
# Ohio                    18
# Oklahoma                18
# Oregon                  18
# Rhode Island            18
# Montana                 18
# South Carolina          18
# South Dakota            18
# Tennessee               18
# Texas                   18
# Utah                    18
# Vermont                 18
# Virginia                18
# Washington              18
# West Virginia           18
# Wisconsin               18
# Nebraska                18
# Missouri                18
# Alaska                  18
# Idaho                   18
# Arizona                 18
# Arkansas                18
# California              18
# Colorado                18
# Connecticut             18
# Delaware                18
# ...

# %%
# Top 10 states
plt.figure(figsize=(12,6))
df['year'].value_counts().nlargest(10).plot(kind='bar')
plt.show()

# %%
#df['drug_deaths'].sum()

df1 = df.iloc[ : , [0,3]]
#df.groupby(['year']).sum()

# %%
d_f=df1.groupby('state').sum()

# %%
d_f=d_f.reset_index()
df
plt.figure(figsize=(12,6))
sns.barplot(data=d_f, x='state', y ="drug_deaths")
plt.xticks(rotation=90)
plt.show()

# %%
df1.max()
# Out:
# state          Wyoming
# drug_deaths       5094
# dtype: object

# %%
df1.min()
# Out:
# state          Alabama
# drug_deaths         13
# dtype: object

# %%
df2 = df.iloc[ : , [2,3]]
df2
# Out:
#      year  drug_deaths
# 0    1999          195
# 1    2000          232
# 2    2001          253
# 3    2002          248
# 4    2003          255
# ..    ...          ...
# 913  2012           99
# 914  2013           99
# 915  2014          112
# 916  2015           99
# 917  2016          103
#
# [918 rows x 2 columns]

# %%
df3=df2.groupby('year').sum()
df3
# Out:
#       drug_deaths
# year
# 1999        19128
# 2000        19720
# 2001        21705
# 2002        26040
# 2003        28723
# 2004        30711
# 2005        33541
# 2006        38396
# 2007        38371
# 2008        38649
# 2009        39147
# 2010        40393
# 2011        43544
# 2012        43819
# 2013        46471
# 2014        49714
# 2015        55403
# 2016        67265

# %%
df1=df1.reset_index()
df1
#plt.figure(figsize=(12,6))
#sns.barplot(data=df1, x='state', y ="drug_deaths")
#plt.xticks(rotation=90)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SKENTE~1\AppData\Local\Temp/ipykernel_9088/3709852275.py in <module>
# ----> 1 df1=df1.reset_index()
#       2 df1
#       3 #plt.figure(figsize=(12,6))
#       4 #sns.barplot(data=df1, x='state', y ="drug_deaths")
#       5 #plt.xticks(rotation=90)
#
# NameError: name 'df1' is not defined

# %%
df3=df3.reset_index()
df3
plt.figure(figsize=(12,6))
sns.barplot(data=df3, x='year', y ="drug_deaths")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df, x='state', y ="drug_deaths")
plt.xticks(rotation=90)
plt.show()

# %%
df.drop(df['state_code',''])

# %%
plt.figure(figsize=(12,6))
sns.countplot(df["year"])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\SK Enterprises\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df, x='state', y ="drug_deaths")
plt.xticks(rotation=90)
plt.show()

# %%
round(df.corr(), 2)
# Out:
#                          state_code  year  drug_deaths  population  \
# state_code                     1.00 -0.00        -0.07       -0.08
# year                          -0.00  1.00         0.28        0.04
# drug_deaths                   -0.07  0.28         1.00        0.89
# population                    -0.08  0.04         0.89        1.00
# labor_force                   -0.08  0.03         0.88        1.00
# employment                    -0.07  0.02         0.88        1.00
# unemployment                  -0.10  0.12         0.85        0.92
# unemployment_rate             -0.12  0.34         0.28        0.20
# cpi_all_urban_consumers        0.00  0.99         0.27        0.04
# gdp_per_capita                -0.18  0.10        -0.03       -0.03
#
#                          labor_force  employment  unemployment  \
# state_code                     -0.08       -0.07         -0.10
# year                            0.03        0.02          0.12
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(round(df.corr(),2),annot=True)
# Out:
# <AxesSubplot:>

# %%
di=df.groupby('state')

# %%
sns.lineplot(x='drug_deaths',y='population',data=df)
# Out:
# <AxesSubplot:xlabel='drug_deaths', ylabel='population'>

# %%
df
# Out:
#        state  state_code  year  drug_deaths  population  labor_force  \
# 0    Alabama           1  1999          195     4430141      2140296
# 1    Alabama           1  2000          232     4447100      2133223
# 2    Alabama           1  2001          253     4467634      2115401
# 3    Alabama           1  2002          248     4480089      2106161
# 4    Alabama           1  2003          255     4503491      2120225
# ..       ...         ...   ...          ...         ...          ...
# 913  Wyoming          56  2012           99      576412       307267
# 914  Wyoming          56  2013           99      582658       306608
# 915  Wyoming          56  2014          112      584153       306331
# 916  Wyoming          56  2015           99      586107       304775
# 917  Wyoming          56  2016          103      585501       300922
#
#      employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# ...

# %%
top_5=df.sort_values(by='drug_deaths',ascending=False).head()
top_5
# Out:
#             state  state_code  year  drug_deaths  population  labor_force  \
# 89     California           6  2016         5094    39250017     19093658
# 88     California           6  2015         5025    39144818     18896477
# 179       Florida          12  2016         4963    20612439      9846000
# 87     California           6  2014         4816    38802500     18758399
# 701  Pennsylvania          42  2016         4762    12784227      6452812
#
#      employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# 89     18048827       1044831                5.5                  240.007
# 88     17724799       1171678                6.2                  237.017
# 179     9373059        472941                4.8                  240.007
# 87     17351318       1407081                7.5                  236.736
# 701     6105223        347589                5.4                  240.007
#
#      gdp_per_capita
# 89            59117
# 88            57596
# ...

# %%
df_g=df.groupby('state')['drug_deaths'].count()
df_g.reset_index()
b_p=px.bar(df_g,x='state',y='drug_deaths')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SKENTE~1\AppData\Local\Temp/ipykernel_9088/3852229463.py in <module>
#       1 df_g=df.groupby('state')['drug_deaths'].count()
#       2 df_g.reset_index()
# ----> 3 b_p=px.bar(df_g,x='state',y='drug_deaths')
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     371     mark.
# ...

# %%
g_ph=px.bar(df,x='state',y='drug_deaths',color='unemployment',orientation='v')
g_ph

# %%
plt.figure(figsize=(14,6))
sns.lineplot(x='cpi_all_urban_consumers',y='gdp_per_capita',data=df)
# Out:
# <AxesSubplot:xlabel='cpi_all_urban_consumers', ylabel='gdp_per_capita'>
