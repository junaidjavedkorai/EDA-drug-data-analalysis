# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import plotly.express as px

# %%
# 1. LOADING THE DATSET 
df= pd.read_csv('drug_abuse_data.csv')
df
# Out:
#        state  state_code  year  drug_deaths  population  labor_force  \
# 0    Alabama           1  1999          195     4430141      2140296
# 1    Alabama           1  2000          232     4447100      2133223
# 2    Alabama           1  2001          253     4467634      2115401
# 3    Alabama           1  2002          248     4480089      2106161
# 4    Alabama           1  2003          255     4503491      2120225
# ..       ...         ...   ...          ...         ...          ...
# 913  Wyoming          56  2012           99      576412       307267
# 914  Wyoming          56  2013           99      582658       306608
# 915  Wyoming          56  2014          112      584153       306331
# 916  Wyoming          56  2015           99      586107       304775
# 917  Wyoming          56  2016          103      585501       300922
#
#      employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# 0       2038889        101407                4.7                  166.600
# 1       2035594         97629                4.6                  172.200
# 2       2006884        108517                5.1                  177.100
# 3       1981919        124242                5.9                  179.900
# 4       1992732        127493                6.0                  184.000
# ..          ...           ...                ...                      ...
# 913      290932         16335                5.3                  229.594
# 914      292131         14477                4.7                  232.957
# 915      293657         12674                4.1                  236.736
# 916      291686         13089                4.3                  237.017
# 917      285052         15870                5.3                  240.007
#
#      gdp_per_capita
# 0             33106
# 1             33106
# 2             33312
# 3             34068
# 4             34855
# ..              ...
# 913           60777
# 914           60770
# 915           60900
# 916           60979
# 917           60004
#
# [918 rows x 11 columns]

# %%
# 2. Checking the shape and size of Data set 
df.shape
rows,cols=df.shape
print('Number of Rows :',rows)
print('Number of Columns :',cols)
# Out:
# Number of Rows : 918
# Number of Columns : 11

# %%
df.size   #Overall Values
# Out:
# 10098

# %%
df1=df.rename(columns={'state':'state','state_code':'s_code','year':'year','drug_deaths':'drg_deaths','population':'popu','labor_force':'l_f','employment':'emp','unemployment':'unemp','cpi_all_urban_consumers':'cpi','gdp_per_capita':'gdp'})
df1
# Out:
#        state  s_code  year  drg_deaths     popu      l_f      emp   unemp  \
# 0    Alabama       1  1999         195  4430141  2140296  2038889  101407
# 1    Alabama       1  2000         232  4447100  2133223  2035594   97629
# 2    Alabama       1  2001         253  4467634  2115401  2006884  108517
# 3    Alabama       1  2002         248  4480089  2106161  1981919  124242
# 4    Alabama       1  2003         255  4503491  2120225  1992732  127493
# ..       ...     ...   ...         ...      ...      ...      ...     ...
# 913  Wyoming      56  2012          99   576412   307267   290932   16335
# 914  Wyoming      56  2013          99   582658   306608   292131   14477
# 915  Wyoming      56  2014         112   584153   306331   293657   12674
# 916  Wyoming      56  2015          99   586107   304775   291686   13089
# 917  Wyoming      56  2016         103   585501   300922   285052   15870
#
#      unemployment_rate      cpi    gdp
# 0                  4.7  166.600  33106
# 1                  4.6  172.200  33106
# 2                  5.1  177.100  33312
# 3                  5.9  179.900  34068
# 4                  6.0  184.000  34855
# ..                 ...      ...    ...
# 913                5.3  229.594  60777
# 914                4.7  232.957  60770
# 915                4.1  236.736  60900
# 916                4.3  237.017  60979
# 917                5.3  240.007  60004
#
# [918 rows x 11 columns]

# %%
#SUMMARY OF DATASETS
print(f""" There are {df1.state.nunique()} states are covered in the dataset and deaths in {df1.year.nunique()} years from {df1.year.min()} to {df1.year.max()} due to drugs are recorded. Overall {df1.drg_deaths.sum()} deaths are recorded in different states""")
# Out:
#  There are 51 states are covered in the dataset and deaths in 18 years from 1999 to 2016 due to drugs are recorded. Overall 680740 deaths are recorded in different states

# %%
# Drop The Unused Column 
df.drop('state_code',axis=1,inplace=True)
df
# Out:
#        state  year  drug_deaths  population  labor_force  employment  \
# 0    Alabama  1999          195     4430141      2140296     2038889
# 1    Alabama  2000          232     4447100      2133223     2035594
# 2    Alabama  2001          253     4467634      2115401     2006884
# 3    Alabama  2002          248     4480089      2106161     1981919
# 4    Alabama  2003          255     4503491      2120225     1992732
# ..       ...   ...          ...         ...          ...         ...
# 913  Wyoming  2012           99      576412       307267      290932
# 914  Wyoming  2013           99      582658       306608      292131
# 915  Wyoming  2014          112      584153       306331      293657
# 916  Wyoming  2015           99      586107       304775      291686
# 917  Wyoming  2016          103      585501       300922      285052
#
#      unemployment  unemployment_rate  cpi_all_urban_consumers  gdp_per_capita
# 0          101407                4.7                  166.600           33106
# 1           97629                4.6                  172.200           33106
# 2          108517                5.1                  177.100           33312
# 3          124242                5.9                  179.900           34068
# 4          127493                6.0                  184.000           34855
# ..            ...                ...                      ...             ...
# 913         16335                5.3                  229.594           60777
# 914         14477                4.7                  232.957           60770
# 915         12674                4.1                  236.736           60900
# 916         13089                4.3                  237.017           60979
# 917         15870                5.3                  240.007           60004
#
# [918 rows x 10 columns]

# %%
d_f=df.groupby(['state'])
d_f

# %%
df1.min()
# Out:
# state                Alabama
# s_code                     1
# year                    1999
# drg_deaths                13
# popu                  491780
# l_f                   262758
# emp                   250605
# unemp                   8074
# unemployment_rate        2.3
# cpi                    166.6
# gdp                    28856
# dtype: object

# %%
df1.describe()
# Out:
#            s_code         year   drg_deaths          popu           l_f  \
# count  918.000000   918.000000   918.000000  9.180000e+02  9.180000e+02
# mean    28.960784  2007.500000   741.546841  5.921292e+06  2.957883e+06
# std     15.685381     5.190956   833.074622  6.631564e+06  3.253066e+06
# min      1.000000  1999.000000    13.000000  4.917800e+05  2.627580e+05
# 25%     16.000000  2003.000000   168.000000  1.599830e+06  7.696502e+05
# 50%     29.000000  2007.500000   514.000000  4.131636e+06  1.991038e+06
# 75%     42.000000  2012.000000   963.500000  6.686474e+06  3.470114e+06
# max     56.000000  2016.000000  5094.000000  3.925002e+07  1.909366e+07
#
#                 emp         unemp  unemployment_rate         cpi  \
# count  9.180000e+02  9.180000e+02         918.000000  918.000000
# mean   2.776227e+06  1.816554e+05           5.716776  206.782667
# std    3.032583e+06  2.409780e+05           1.985356   23.726850
# min    2.506050e+05  8.074000e+03           2.300000  166.600000
# 25%    7.258050e+05  3.914950e+04           4.300000  184.000000
# 50%    1.869140e+06  1.092125e+05           5.300000  210.939500
# 75%    3.246838e+06  2.175358e+05           6.775000  229.594000
# max    1.804883e+07  2.244326e+06          13.700000  240.007000
#
#                  gdp
# count     918.000000
# mean    48098.793028
# std     17896.631888
# min     28856.000000
# 25%     39598.250000
# 50%     44623.500000
# 75%     51409.750000
# max    170687.000000

# %%
df1.iloc[df1['drg_deaths'].idxmax()]
# Out:
# state                California
# s_code                        6
# year                       2016
# drg_deaths                 5094
# popu                   39250017
# l_f                    19093658
# emp                    18048827
# unemp                   1044831
# unemployment_rate           5.5
# cpi                     240.007
# gdp                       59117
# Name: 89, dtype: object

# %%
df1.iloc[df1['drg_deaths'].idxmin()]
# Out:
# state                North Dakota
# s_code                         38
# year                         2005
# drg_deaths                     13
# popu                       646089
# l_f                        355545
# emp                        343508
# unemp                       12037
# unemployment_rate             3.4
# cpi                         195.3
# gdp                         41272
# Name: 618, dtype: object

# %% [markdown]
# # -EDA

# %%
df.min()
# Out:
# state                      Alabama
# state_code                       1
# year                          1999
# drug_deaths                     13
# population                  491780
# labor_force                 262758
# employment                  250605
# unemployment                  8074
# unemployment_rate              2.3
# cpi_all_urban_consumers      166.6
# gdp_per_capita               28856
# dtype: object

# %%
plt.figure(figsize=(25,8))
unemp_gdp=df.groupby('year').unemployment_rate.sum().to_frame().reset_index()
unemp_gdp.columns = ['year','unemployment_rate']
sns.barplot(y=unemp_gdp.unemployment_rate,x=unemp_gdp.year,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Unemployment_rate in each year')
plt.show()

# %%
fig=px.scatter(df,y='cpi_all_urban_consumers',x='year',color='drug_deaths')
fig.show()

# %%
fig=px.bar(df,y='cpi_all_urban_consumers' , x='year' )
fig.show()

# %%
plt.figure(figsize=(12,6))
year_death=df.groupby('year').drug_deaths.sum().to_frame().reset_index()
year_death.columns = ['year','drug_deaths']
sns.barplot(x=year_death.year,y=year_death.drug_deaths,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',10))
#sns.barplot(x=year_death.year,y=year_death.drug_deaths)
plt.xticks(rotation=90)
plt.title('Number of Drug_Deaths in Each Year')
plt.show()

# %%
plt.figure(figsize=(12,6))
count_deaths=df.groupby('state').drug_deaths.sum().to_frame().reset_index().sort_values('drug_deaths',ascending=False)
#sns.barplot(x=count_deaths.state , y=count_deaths.drug_deaths,palette='RdYlGn_r',edgecolor=sns.color_palette('dark',10))
sns.barplot(x=count_deaths.state , y=count_deaths.drug_deaths)
plt.xticks(rotation=90)
plt.title("Number of Drug_Deaths in Each State")
plt.show()

# %%
corr=df.corr(method='pearson')
corr
# Out:
#                            state_code          year  drug_deaths  population  \
# state_code               1.000000e+00 -1.482165e-13    -0.070278   -0.080176
# year                    -1.482165e-13  1.000000e+00     0.278011    0.040287
# drug_deaths             -7.027804e-02  2.780109e-01     1.000000    0.887804
# population              -8.017580e-02  4.028688e-02     0.887804    1.000000
# labor_force             -7.658850e-02  3.153209e-02     0.883867    0.999141
# employment              -7.396101e-02  2.432075e-02     0.880805    0.998488
# unemployment            -1.031402e-01  1.196012e-01     0.847217    0.922386
# unemployment_rate       -1.234715e-01  3.428283e-01     0.275715    0.202155
# cpi_all_urban_consumers  7.968988e-15  9.939331e-01     0.272135    0.040163
# gdp_per_capita          -1.849001e-01  1.049666e-01    -0.030262   -0.028447
#
#                          labor_force  employment  unemployment  \
# state_code                 -0.076588   -0.073961     -0.103140
# year                        0.031532    0.024321      0.119601
# drug_deaths                 0.883867    0.880805      0.847217
# population                  0.999141    0.998488      0.922386
# labor_force                 1.000000    0.999521      0.920982
# employment                  0.999521    1.000000      0.908479
# unemployment                0.920982    0.908479      1.000000
# unemployment_rate           0.194559    0.175005      0.424098
# cpi_all_urban_consumers     0.031847    0.024149      0.126023
# gdp_per_capita             -0.022146   -0.022267     -0.018743
#
#                          unemployment_rate  cpi_all_urban_consumers  \
# state_code                       -0.123472             7.968988e-15
# year                              0.342828             9.939331e-01
# drug_deaths                       0.275715             2.721353e-01
# population                        0.202155             4.016280e-02
# labor_force                       0.194559             3.184720e-02
# employment                        0.175005             2.414851e-02
# unemployment                      0.424098             1.260226e-01
# unemployment_rate                 1.000000             3.629319e-01
# cpi_all_urban_consumers           0.362932             1.000000e+00
# gdp_per_capita                    0.065744             1.066655e-01
#
#                          gdp_per_capita
# state_code                    -0.184900
# year                           0.104967
# drug_deaths                   -0.030262
# population                    -0.028447
# labor_force                   -0.022146
# employment                    -0.022267
# unemployment                  -0.018743
# unemployment_rate              0.065744
# cpi_all_urban_consumers        0.106666
# gdp_per_capita                 1.000000

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b0832_row0_col0, #T_b0832_row1_col1, #T_b0832_row2_col2, #T_b0832_row3_col3, #T_b0832_row3_col4, #T_b0832_row3_col5, #T_b0832_row4_col3, #T_b0832_row4_col4, #T_b0832_row4_col5, #T_b0832_row5_col3, #T_b0832_row5_col4, #T_b0832_row5_col5, #T_b0832_row6_col6, #T_b0832_row7_col7, #T_b0832_row8_col8, #T_b0832_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b0832_row0_col1, #T_b0832_row0_col2, #T_b0832_row0_col3, #T_b0832_row0_col4, #T_b0832_row0_col5, #T_b0832_row0_col6, #T_b0832_row0_col7, #T_b0832_row0_col8, #T_b0832_row0_col9, #T_b0832_row9_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b0832_row1_col0, #T_b0832_row8_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b0832_row1_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b0832_row1_col3, #T_b0832_row8_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b0832_row1_col4, #T_b0832_row8_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b0832_row1_col5, #T_b0832_row4_col0, #T_b0832_row5_col0, #T_b0832_row8_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b0832_row1_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_b0832_row1_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b0832_row1_col8, #T_b0832_row8_col1 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_b0832_row1_col9, #T_b0832_row8_col9 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b0832_row2_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b0832_row2_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b0832_row2_col3, #T_b0832_row3_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_b0832_row2_col4, #T_b0832_row4_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_b0832_row2_col5, #T_b0832_row5_col2 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_b0832_row2_col6 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_b0832_row2_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b0832_row2_col8 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b0832_row2_col9, #T_b0832_row3_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b0832_row3_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b0832_row3_col1, #T_b0832_row3_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b0832_row3_col6, #T_b0832_row4_col6, #T_b0832_row6_col3, #T_b0832_row6_col4 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_b0832_row3_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_b0832_row4_col1, #T_b0832_row4_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_b0832_row4_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_b0832_row4_col9, #T_b0832_row5_col9, #T_b0832_row6_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b0832_row5_col1, #T_b0832_row5_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b0832_row5_col6, #T_b0832_row6_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_b0832_row5_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b0832_row6_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b0832_row6_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b0832_row6_col2 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_b0832_row6_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_b0832_row6_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b0832_row7_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b0832_row7_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b0832_row7_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b0832_row7_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b0832_row7_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b0832_row7_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b0832_row7_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_b0832_row7_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b0832_row7_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b0832_row8_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b0832_row8_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_b0832_row8_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_b0832_row9_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b0832_row9_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_b0832_row9_col3, #T_b0832_row9_col4, #T_b0832_row9_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b0832_row9_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_b0832_row9_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_b0832_row9_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0832_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state_code</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >drug_deaths</th>
#       <th class="col_heading level0 col3" >population</th>
#       <th class="col_heading level0 col4" >labor_force</th>
#       <th class="col_heading level0 col5" >employment</th>
#       <th class="col_heading level0 col6" >unemployment</th>
#       <th class="col_heading level0 col7" >unemployment_rate</th>
#       <th class="col_heading level0 col8" >cpi_all_urban_consumers</th>
#       <th class="col_heading level0 col9" >gdp_per_capita</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0832_level0_row0" class="row_heading level0 row0" >state_code</th>
#       <td id="T_b0832_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b0832_row0_col1" class="data row0 col1" >-0.000000</td>
#       <td id="T_b0832_row0_col2" class="data row0 col2" >-0.070278</td>
#       <td id="T_b0832_row0_col3" class="data row0 col3" >-0.080176</td>
#       <td id="T_b0832_row0_col4" class="data row0 col4" >-0.076588</td>
#       <td id="T_b0832_row0_col5" class="data row0 col5" >-0.073961</td>
#       <td id="T_b0832_row0_col6" class="data row0 col6" >-0.103140</td>
#       <td id="T_b0832_row0_col7" class="data row0 col7" >-0.123472</td>
#       <td id="T_b0832_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_b0832_row0_col9" class="data row0 col9" >-0.184900</td>
#     </tr>
#     <tr>
#       <th id="T_b0832_level0_row1" class="row_heading level0 row1" >year</th>
#       <td id="T_b0832_row1_col0" class="data row1 col0" >-0.000000</td>
#       <td id="T_b0832_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b0832_row1_col2" class="data row1 col2" >0.278011</td>
#       <td id="T_b0832_row1_col3" class="data row1 col3" >0.040287</td>
#       <td id="T_b0832_row1_col4" class="data row1 col4" >0.031532</td>
#       <td id="T_b0832_row1_col5" class="data row1 col5" >0.024321</td>
#       <td id="T_b0832_row1_col6" class="data row1 col6" >0.119601</td>
#       <td id="T_b0832_row1_col7" class="data row1 col7" >0.342828</td>
#       <td id="T_b0832_row1_col8" class="data row1 col8" >0.993933</td>
#       <td id="T_b0832_row1_col9" class="data row1 col9" >0.104967</td>
#     </tr>
#     <tr>
#       <th id="T_b0832_level0_row2" class="row_heading level0 row2" >drug_deaths</th>
#       <td id="T_b0832_row2_col0" class="data row2 col0" >-0.070278</td>
#       <td id="T_b0832_row2_col1" class="data row2 col1" >0.278011</td>
#       <td id="T_b0832_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b0832_row2_col3" class="data row2 col3" >0.887804</td>
#       <td id="T_b0832_row2_col4" class="data row2 col4" >0.883867</td>
#       <td id="T_b0832_row2_col5" class="data row2 col5" >0.880805</td>
#       <td id="T_b0832_row2_col6" class="data row2 col6" >0.847217</td>
#       <td id="T_b0832_row2_col7" class="data row2 col7" >0.275715</td>
#       <td id="T_b0832_row2_col8" class="data row2 col8" >0.272135</td>
#       <td id="T_b0832_row2_col9" class="data row2 col9" >-0.030262</td>
#     </tr>
#     <tr>
#       <th id="T_b0832_level0_row3" class="row_heading level0 row3" >population</th>
#       <td id="T_b0832_row3_col0" class="data row3 c
