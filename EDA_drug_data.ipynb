# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
# LOAD THE DATASET 

drug_data=pd.read_csv(r'C:\Users\Junaid Javed\EDA_DRUG_DATA\drug_abuse_data.csv')
drug_data.head(10)
# Out:
#      state  state_code  year  drug_deaths  population  labor_force  \
# 0  Alabama           1  1999          195     4430141      2140296
# 1  Alabama           1  2000          232     4447100      2133223
# 2  Alabama           1  2001          253     4467634      2115401
# 3  Alabama           1  2002          248     4480089      2106161
# 4  Alabama           1  2003          255     4503491      2120225
# 5  Alabama           1  2004          327     4530729      2136458
# 6  Alabama           1  2005          332     4569805      2146025
# 7  Alabama           1  2006          466     4628981      2167809
# 8  Alabama           1  2007          554     4672840      2175612
# 9  Alabama           1  2008          646     4718206      2176489
#
#    employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# 0     2038889        101407                4.7                  166.600
# 1     2035594         97629                4.6                  172.200
# ...

# %%
drug_data.drop_duplicates(subset='labor_force',keep=False ,inplace=True)
drug_data
# Out:
#        state  state_code  year  drug_deaths  population  labor_force  \
# 0    Alabama           1  1999          195     4430141      2140296
# 1    Alabama           1  2000          232     4447100      2133223
# 2    Alabama           1  2001          253     4467634      2115401
# 3    Alabama           1  2002          248     4480089      2106161
# 4    Alabama           1  2003          255     4503491      2120225
# ..       ...         ...   ...          ...         ...          ...
# 913  Wyoming          56  2012           99      576412       307267
# 914  Wyoming          56  2013           99      582658       306608
# 915  Wyoming          56  2014          112      584153       306331
# 916  Wyoming          56  2015           99      586107       304775
# 917  Wyoming          56  2016          103      585501       300922
#
#      employment  unemployment  unemployment_rate  cpi_all_urban_consumers  \
# ...

# %%
drug_data.max()
# Out:
# state                       Wyoming
# state_code                       56
# year                           2016
# drug_deaths                    5094
# population                 39250017
# labor_force                19093658
# employment                 18048827
# unemployment                2244326
# unemployment_rate              13.7
# cpi_all_urban_consumers     240.007
# gdp_per_capita               170687
# dtype: object

# %%
drug_data.min()
# Out:
# state                      Alabama
# state_code                       1
# year                          1999
# drug_deaths                     13
# population                  491780
# labor_force                 262758
# employment                  250605
# unemployment                  8074
# unemployment_rate              2.3
# cpi_all_urban_consumers      166.6
# gdp_per_capita               28856
# dtype: object

# %%
drug_data.median()
# Out:
# C:\Users\Junaid Javed\AppData\Local\Temp\ipykernel_6728\3373997346.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   drug_data.median()
# state_code                 2.900000e+01
# year                       2.007500e+03
# drug_deaths                5.140000e+02
# population                 4.131636e+06
# labor_force                1.991038e+06
# employment                 1.869140e+06
# unemployment               1.092125e+05
# unemployment_rate          5.300000e+00
# cpi_all_urban_consumers    2.109395e+02
# gdp_per_capita             4.462350e+04
# dtype: float64

# %%
drug_data.mean()
# Out:
# C:\Users\Junaid Javed\AppData\Local\Temp\ipykernel_6728\4042452631.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   drug_data.mean()
# state_code                 2.896078e+01
# year                       2.007500e+03
# drug_deaths                7.415468e+02
# population                 5.921292e+06
# labor_force                2.957883e+06
# employment                 2.776227e+06
# unemployment               1.816554e+05
# unemployment_rate          5.716776e+00
# cpi_all_urban_consumers    2.067827e+02
# gdp_per_capita             4.809879e+04
# dtype: float64

# %%
drug_data.isnull().sum()
# Out:
# state                      0
# state_code                 0
# year                       0
# drug_deaths                0
# population                 0
# labor_force                0
# employment                 0
# unemployment               0
# unemployment_rate          0
# cpi_all_urban_consumers    0
# gdp_per_capita             0
# dtype: int64

# %%
drug_data.nunique()
# Out:
# state                       51
# state_code                  51
# year                        18
# drug_deaths                670
# population                 918
# labor_force                918
# employment                 918
# unemployment               916
# unemployment_rate           93
# cpi_all_urban_consumers     18
# gdp_per_capita             906
# dtype: int64

# %%
drug_data.count()
# Out:
# state                      918
# state_code                 918
# year                       918
# drug_deaths                918
# population                 918
# labor_force                918
# employment                 918
# unemployment               918
# unemployment_rate          918
# cpi_all_urban_consumers    918
# gdp_per_capita             918
# dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
# UNIVARIATE ANALYSIS
# 1. Barplot
# 2. Count Plot
# 3. Hist Plot
# 4. Pie Chart
# 5. Bar Chart

# %%
# BAR PLOT  
sns.barplot(drug_data['drug_deaths'])
# Out:
# C:\Users\Junaid Javed\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='drug_deaths'>

# %%
# HIST PLOT 
sns.histplot(drug_data['labor_force'])
# Out:
# <AxesSubplot:xlabel='labor_force', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='drug_deaths',y='population',data=drug_data)
# Out:
# <AxesSubplot:xlabel='drug_deaths', ylabel='population'>

# %%
co_r=drug_data.corr(method='pearson')

# %%
sns.pairplot(co_r)

# %%
sns.heatmap(co_r,annot=True)
# Out:
# <AxesSubplot:>

# %%
df=drug_data.iloc[0:,2:4]
df
# Out:
#      year  drug_deaths
# 0    1999          195
# 1    2000          232
# 2    2001          253
# 3    2002          248
# 4    2003          255
# ..    ...          ...
# 913  2012           99
# 914  2013           99
# 915  2014          112
# 916  2015           99
# 917  2016          103
#
# [918 rows x 2 columns]

# %%
df.groupby('year').sum()
# Out:
#       drug_deaths
# year
# 1999        19128
# 2000        19720
# 2001        21705
# 2002        26040
# 2003        28723
# 2004        30711
# 2005        33541
# 2006        38396
# 2007        38371
# 2008        38649
# 2009        39147
# 2010        40393
# 2011        43544
# 2012        43819
# 2013        46471
# 2014        49714
# 2015        55403
# 2016        67265

# %%
pip install tkinker
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tkinker (from versions: none)
# ERROR: No matching distribution found for tkinker
